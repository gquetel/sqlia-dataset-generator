# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np 
import pandas as pd

# %%
dataset_path = "/home/gquetel/experience-results/2025-06-14-dataset-generation/full-training/dataset.csv"
full = True

df = pd.read_csv(
    dataset_path,
    # dtype is specified to prevent a DtypeWarning
    dtype={
        "full_query": str,
        "label": int,
        "statement_type": str,
        "query_template_id": str,
        "attack_payload": str,
        "attack_id": str,
        "attack_technique": str,
        "split": str,
        "sqlmap_status": str,
        "attack_stage": str,
    },
)
# Out:
# /tmp/ipykernel_50717/1113182750.py:4: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
mask_atk = df["label"] == 1
mask_n = df["label"] == 0

# %%
df_a = df[mask_atk]
display(df_a)
# Out:
#                                                full_query  label  \
# 0       INSERT INTO airport (ident, type, name, latitu...      1
# 1       INSERT INTO airport (ident, type, name, latitu...      1
# 2       INSERT INTO airport (ident, type, name, latitu...      1
# 3       INSERT INTO airport (ident, type, name, latitu...      1
# 4       INSERT INTO airport (ident, type, name, latitu...      1
# ...                                                   ...    ...
# 281915  SELECT a.name AS airport_name,a.municipality,C...      1
# 281916  SELECT a.name AS airport_name,a.municipality,C...      1
# 281917  SELECT a.name AS airport_name,a.municipality,C...      1
# 281918  SELECT a.name AS airport_name,a.municipality,C...      1
# 281919  SELECT a.name AS airport_name,a.municipality,C...      1
#
#                                               user_inputs attack_stage  \
# 0        BR-1817 small_airport Cloud County Health Cen...        recon
# ...

# %%
df_n = df[mask_n]
display(df_n)
# Out:
#                                                 full_query  label  \
# 281920            DELETE FROM countries WHERE code = "BQ";      0
# 281921   SELECT a.id, a.name, a.municipality, a.iso_cou...      0
# 281922   UPDATE airport SET wikipedia_link = "https://e...      0
# 281923   SELECT name, 'airport' AS entity_type FROM air...      0
# 281924   INSERT INTO airport_frequencies (id, airport_r...      0
# ...                                                    ...    ...
# 3101115  INSERT INTO countries (code, name, continent) ...      0
# 3101116           DELETE FROM countries WHERE code = "QA";      0
# 3101117  SELECT a.name, a.municipality, a.iso_country F...      0
# 3101118  SELECT a.name, a.municipality, a.iso_country F...      0
# 3101119  SELECT * FROM airport WHERE gps_code = "YDVR" ...      0
#
#                                                user_inputs attack_stage  \
# 281920                                                  BQ          NaN
# ...

# %%
common_queries = set(df_a['full_query']) & set(df_n['full_query'])
print(len(common_queries))
# Out:
# 209
